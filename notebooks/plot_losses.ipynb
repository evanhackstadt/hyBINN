# %%
# Plot losses recorded from specified runs in experiments/

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
run_dir = "../experiments/runs/ablation/binn/binn_no_dropout/"
csv_path = os.path.join(run_dir, f"train_results_binn_no_dropout.csv")

df = pd.read_csv(csv_path, index_col=0)
df.head()
# Out:
#    fold  epoch  train_loss  val_loss  cindexes
# 0     1      1    0.761937  2.968789  0.519582
# 1     1      2    0.836006  2.968374  0.510183
# 2     1      3    0.719129  2.962663  0.562924
# 3     1      4    0.605421  2.968563  0.660052
# 4     1      5    0.591276  3.148207  0.691384

# %%
# convert to long format for seaborn plotting
# dfm = df.melt(id_vars='epoch', var_name='type', value_name='loss')
# dfm.head()

# %%
ax = sns.lineplot(df, x='epoch', y='cindexes')

# fig = ax.get_figure()
# fig.savefig(os.path.join(run_dir, f"run4_loss.png"))

# %%
ax = sns.lineplot(df, x='epoch', y='cindexes')
ax.set_ylim(0, 1)
ax.set_yticks([0, 0.25, 0.5, 0.75, 1.0])

# fig = ax.get_figure()
# fig.savefig(os.path.join(run_dir, f"run4_cindex.png"))

# %%
run_dir = "../experiments/runs/ablation/binn_clinical/"
csv_path = os.path.join(run_dir, f"train_results_by_epoch.csv")

df2 = pd.read_csv(csv_path, index_col=0)
df2.head()
# Out:
#    fold  epoch  train_loss  val_loss    cindex
# 0     1      1    0.813953  2.956902  0.631332
# 1     1      2    0.777988  2.942756  0.593734
# 2     1      3    0.719153  2.937152  0.567102
# 3     1      4    0.725240  2.924813  0.580157
# 4     1      5    0.663644  2.891797  0.630287

# %%
ax = sns.lineplot(df, x='epoch', y='cindexes')

# %%
ax = sns.lineplot(df, x='epoch', y='cindexes')
ax.set_ylim(0, 1)
ax.set_yticks([0, 0.25, 0.5, 0.75, 1.0])
